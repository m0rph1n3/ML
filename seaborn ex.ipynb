# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'], kde =False)

# %%
sns.distplot(tips['total_bill'], kde =False, bins = 75)

# %%
# total bill com tip
sns.jointplot(x='total_bill', y='tip', data =tips, kind = 'reg')

# %%
sns.jointplot(x='total_bill', y='tip', data =tips, kind = 'hex')

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = 'sex')

# %%
sns.rugplot(tips['total_bill'])
#para achar o KDE

# %%
sns.kdeplot(tips['total_bill'])

# %%
#plots categoricos

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#barplot
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
sns.barplot(x='sex',y='total_bill',data=tips, estimator =np.std)

# %%
sns.countplot(x='sex',data =tips)

# %%
sns.boxplot(x='day',y='total_bill',data = tips)

# %%
sns.boxplot(x='day',y='total_bill',data = tips,hue ='sex')

# %%
sns.violinplot(x='day', y='tip',data=tips)

# %%
sns.violinplot(x='day', y='tip',data=tips,hue ='sex')

# %%
sns.violinplot(x='day', y='tip',data=tips,hue ='sex', split =True)

# %%
sns.stripplot(x='day', y='total_bill',data=tips)

# %%
sns.swarmplot(x='day', y='tip',data=tips,hue = 'sex')

# %%
sns.factorplot(x='day', y='total_bill',data=tips ,kind ='box')
#kind pode ser um dos tipos acima
# Out:
# C:\Users\warhouse\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#plot matrixiais

flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights_crr = flights.corr()
tips_crr = tips.corr()

# %%
flights_crr
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
tips_crr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(flights_crr)

# %%
sns.heatmap(tips_crr, annot = True)

# %%
flights.info
# Out:
# <bound method DataFrame.info of      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# ...

# %%
pvt_flights =flights.pivot_table(values='passengers',index= 'month',columns = 'year')

# %%
pvt_flights.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
sns.heatmap(pvt_flights)

# %%
sns.clustermap(pvt_flights, standard_scale =1 )

# %%
#plots de regressao
#llinear model

sns.lmplot(x='total_bill', y = 'tip', data = tips ,hue ='sex')
#markers =['o','v']

# %%
sns.lmplot(x='total_bill', y = 'tip', data = tips ,hue ='sex',col ='sex')

# %%
sns.lmplot(x='total_bill', y = 'tip', data = tips ,hue ='sex',col ='sex',row ='time')

# %%
#pair grid

iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
g = sns.PairGrid(iris)

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
sns.pairplot(iris,hue = 'species')

# %%
g = sns.FacetGrid(tips,col='time',row ='smoker')
g.map(plt.hist, 'total_bill')

# %%
#styles

sns.set_style
